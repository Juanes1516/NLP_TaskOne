# %% [markdown]
# ## PUNTO # 4 GENSIM
#
# Este punto tiene como objetivo replicar las funcionalidades del punto 104
# anterior utilizando la librería Gensim, una herramienta especializada 105
# en el procesamiento de textos y modelado de tópicos.

# %% [markdown]
# Librerias a Utilizar

# %%
from gensim import corpora
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import preprocess_string
from gensim.parsing.preprocessing import strip_punctuation
from gensim import corpora
from gensim import models
from gensim import similarities
import pandas as pd
import os
import re
import gensim
import numpy as np

# %% [markdown]
# ### Rutas que apuntan a la Data
#
# Las siguientes rutas deberán ser modificadas para acceder a los archivos de datos

# %%
path_docs = './data/docs-raw-texts' #path de los documentos
path_queries = './data/queries-raw-texts'
ground_truth_path = './data/relevance-judgments.tsv'  #path de lectura del ground-truth
salidaFile = "GESIM-consultas_resultados.tsv"  #path para exportación de resultados GENSIM

# %% [markdown]
# ### Extracción del texto
# Para extraer los datos hacemos uso de una expresión regular, al igual que hemos hecho en los anteriores puntos. Así traeremos el texto relevante para nuestro corpus.

# %%
def extraer_texto_relevante(file_content):

    """
    Funcion que extrae el texto que se utilizara de cada documento
    """

    match = re.search(r'<raw><!\[CDATA\[(.*?)\]\]></raw>', file_content, re.DOTALL)

    if match:
        return match.group(1).lower()
    return ""

# %% [markdown]
# ### Creación del Corpus
#
# Tokenización del Corpus del documento al igual que el preprocesamiento de texto por defecto de GENSIM.

# %%
def tokenizar_documentos(path_dir):

    """
    Funcion que crea un corpus que podamos utlizar con la librerpia GENSIM
    """

    # Lista para almacenar los documentos tokenizados
    textos = []
    
    for doc in os.listdir(path_dir):
        path = os.path.join(path_dir, doc)
        with open(path, encoding='utf8') as f:
            file_content = f.read()

            # Extraer el texto relevante
            texto = extraer_texto_relevante(file_content)
          
            # Tokenizar y agregar a la lista de textos
            if texto:
                textos.append(preprocess_string(texto))
               
                
    
    return textos

# %%
corpus = tokenizar_documentos(path_docs)

# %% [markdown]
# Creamos el Vocabulario con base en nuestro corpus y gracias a la pfunción de Gensim

# %%
def crear_vocabulario(corpus):

    vocabulario = corpora.Dictionary(corpus)
    return vocabulario

# %%
vocabulario = crear_vocabulario(corpus)
vocabulario.save('vocabulario_gensim.dict')
vocabulario.token2id
# Out:
# {'accid': 0,
#  'acid': 1,
#  'activ': 2,
#  'affect': 3,
#  'ag': 4,
#  'alexi': 5,
#  'american': 6,
#  'armi': 7,
#  'basi': 8,
#  'beaumont': 9,
#  'beaumont’': 10,
#  'best': 11,
#  'better': 12,
#  'bit': 13,
#  'book': 14,
#  'born': 15,
#  'break': 16,
#  'broken': 17,
#  'canadian': 18,
#  'caus': 19,
#  'chemic': 20,
#  'children': 21,
#  'close': 22,
#  'compani': 23,
#  'complet': 24,
#  'connecticut': 25,
#  'consid': 26,
#  'di': 27,
#  'differ': 28,
#  'digest': 29,
#  'digestion”': 30,
#  'discov': 31,
#  'earli': 32,
#  'emot': 33,
#  'examin': 34,
#  'exist': 35,
#  'expect': 36,
#  'experi': 37,
#  'famou': 38,
#  'find': 39,
#  'fistula': 40,
#  'follow': 41,
#  'food': 42,
#  'fort': 43,
#  'french': 44,
#  'fur': 45,
#  'fuse': 46,
#  'gain': 47,
#  'gastric': 48,
#  'gave': 49,
#  'heal': 50,
#  'hole': 51,
#  'human': 52,
#  'hydrochlor': 53,
#  'imag': 54,
#  'import': 55,
#  'inform': 56,
#  'insert': 57,
#  'insight': 58,
#  'interest': 59,
#  'island': 60,
#  'juic': 61,
#  'june': 62,
#  'knowledg': 63,
#  'known': 64,
#  'leav': 65,
#  'lebanon': 66,
#  'lectur': 67,
#  'mackinac': 68,
#  'main': 69,
#  'man': 70,
#  'martin': 71,
#  'martin’': 72,
#  'mate': 73,
#  'mechan': 74,
#  'mere': 75,
#  'michigan': 76,
#  'movement': 77,
#  'muscl': 78,
#  'name': 79,
#  'natur': 80,
#  'new': 81,
#  'notic': 82,
#  'novemb': 83,
#  'numer': 84,
#  'observ': 85,
#  'old': 86,
#  'open': 87,
#  'order': 88,
#  'outliv': 89,
#  'patient': 90,
#  'pepsin': 91,
#  'perfor': 92,
#  'perform': 93,
#  'period': 94,
#  'perman': 95,
#  'physic': 96,
#  'physician': 97,
#  'physiolog': 98,
#  'physiology”': 99,
#  'plattsburgh': 100,
#  'potenti': 101,
#  'practic': 102,
#  'privat': 103,
#  'process': 104,
#  'protect': 105,
#  'publish': 106,
#  'pull': 107,
#  'quickli': 108,
#  'rang': 109,
#  'refug': 110,
#  'rejoin': 111,
#  'remov': 112,
#  'research': 113,
#  'respons': 114,
#  'rib': 115,
#  'scientist': 116,
#  'serv': 117,
#  'shotgun': 118,
#  'skin': 119,
#  'sourc': 120,
#  'station': 121,
#  'stomach': 122,
#  'store': 123,
#  'string': 124,
#  'suggest': 125,
#  'surgeon': 126,
#  'surgeon’': 127,
#  'surviv': 128,
#  'temperatur': 129,
#  'ti': 130,
#  'trader': 131,
#  'uncomfort': 132,
#  'understand': 133,
#  'video': 134,
#  'war': 135,
#  'went': 136,
#  'william': 137,
#  'work': 138,
#  'wound': 139,
#  'year': 140,
#  'york': 141,
#  'young': 142,
#  'yovisto': 143,
#  '“experi': 144,
#  '“father': 145,
#  'abl': 146,
#  'academi': 147,
#  'accept': 148,
#  'acclaim': 149,
#  'accomplish': 150,
#  'adapt': 151,
#  'adventur': 152,
#  'anim': 153,
#  'animation‘': 154,
#  'antichrist‘': 155,
#  'attempt': 156,
#  'attend': 157,
#  'author': 158,
#  'banknot': 159,
#  'began': 160,
#  'belong': 161,
#  'berl': 162,
#  'bird': 163,
#  'bird’': 164,
#  'boi': 165,
#  'book‘': 166,
#  'catch': 167,
#  'chang': 168,
#  'children’': 169,
#  'church': 170,
#  'colleg': 171,
#  'competit': 172,
#  'cover': 173,
#  'critic': 174,
#  'danish': 175,
#  'delight': 176,
#  'domest': 177,
#  'enabl': 178,
#  'excerpt': 179,
#  'famili': 180,
#  'family’': 181,
#  'farm': 182,
#  'femal': 183,
#  'film': 184,
#  'financi': 185,
#  'fly': 186,
#  'focu': 187,
#  'free': 188,
#  'gees': 189,
#  'genom': 190,
#  'girls’': 191,
#  'good': 192,
#  'goos': 193,
#  'group': 194,
#  'gösta': 195,
#  'hold': 196,
#  'holgersson': 197,
#  'hurt': 198,
#  'itali': 199,
#  'join': 200,
#  'krona': 201,
#  'lagerlöf': 202,
#  'landskrona': 203,
#  'last': 204,
#  'laureat': 205,
#  'learn': 206,
#  'let': 207,
#  'literari': 208,
#  'literatur': 209,
#  'long': 210,
#  'miracl': 211,
#  'neck': 212,
#  'niel': 213,
#  'nil': 214,
#  'nils‘': 215,
#  'nils’': 216,
#  'nobel': 217,
#  'pave': 218,
#  'pictur': 219,
#  'plain': 220,
#  'pleas': 221,
#  'poetri': 222,
#  'popular': 223,
#  'print': 224,
#  'prize': 225,
#  'produc': 226,
#  'receiv': 227,
#  'refus': 228,
#  'regular': 229,
#  'resa': 230,
#  'reveng': 231,
#  'revers': 232,
#  'royal': 233,
#  'saga': 234,
#  'scania': 235,
#  'school': 236,
#  'secondari': 237,
#  'seek': 238,
#  'selma': 239,
#  'seri': 240,
#  'shrunken': 241,
#  'size': 242,
#  'start': 243,
#  'stockholm': 244,
#  'stori': 245,
#  'success': 246,
#  'successfulli': 247,
#  'support': 248,
#  'sverige‘': 249,
#  'sweden': 250,
#  'swedish': 251,
#  'take': 252,
#  'talk': 253,
#  'task': 254,
#  'teach': 255,
#  'teacher': 256,
#  'time': 257,
#  'tini': 258,
#  'tomt': 259,
#  'translat': 260,
#  'travel': 261,
#  'turn': 262,
#  'underbara': 263,
#  'unnot': 264,
#  'wai': 265,
#  'white': 266,
#  'wide': 267,
#  'wild': 268,
#  'win': 269,
#  'wonder': 270,
#  'world': 271,
#  'write': 272,
#  'writer': 273,
#  '‘jerusalem‘': 274,
#  '‘nil': 275,
#  '‘pixar': 276,
#  '‘the': 277,
#  'abandon': 278,
#  'act': 279,
#  'adopt': 280,
#  'africa': 281,
#  'alexandria': 282,
#  'ali': 283,
#  'allow': 284,
#  'appoint': 285,
#  'approv': 286,
#  'april': 287,
#  'arbitr': 288,
#  'architect': 289,
#  'articl': 290,
#  'assist': 291,
#  'associ': 292,
#  'attitud': 293,
#  'avoid': 294,
#  'bankrupt': 295,
#  'baron': 296,
#  'barthélemi': 297,
#  'bbc': 298,
#  'begin': 299,
#  'behalf': 300,
#  'bei': 301,
#  'benjamin': 302,
#  'berkelei': 303,
#  'blow': 304,
#  'bought': 305,
#  'bribe': 306,
#  'britain': 307,
#  'britannica': 308,
#  'british': 309,
#  'canal': 310,
#  'career': 311,
#  'celebr': 312,
#  'centuri': 313,
#  'chargé': 314,
#  'charl': 315,
#  'chose': 316,
#  'circul': 317,
#  'colonel': 318,
#  'commiss': 319,
#  'commissari': 320,
#  'commun': 321,
#  'compagni': 322,
#  'companion': 323,
#  'congress': 324,
#  'construct': 325,
#  'consul': 326,
#  'consular': 327,
#  'contemporari': 328,
#  'continu': 329,
#  'control': 330,
#  'court': 331,
#  'cousin': 332,
#  'cultur': 333,
#  'cut': 334,
#  'deal': 335,
#  'decemb': 336,
#  'decis': 337,
#  'declar': 338,
#  'depart': 339,
#  'despit': 340,
#  'develop': 341,
#  'dig': 342,
#  'diplomat': 343,
#  'direct': 344,
#  'directli': 345,
#  'disagr': 346,
#  'disput': 347,
#  'disra': 348,
#  'distanc': 349,
#  'doom': 350,
#  'drawn': 351,
#  'duti': 352,
#  'd’affair': 353,
#  'east': 354,
#  'educ': 355,
#  'effect': 356,
#  'egypt': 357,
#  'egyptian': 358,
#  'eiffel': 359,
#  'elderli': 360,
#  'emperor': 361,
#  'emploi': 362,
#  'empress': 363,
#  'end': 364,
#  'engin': 365,
#  'enter': 366,
#  'epidem': 367,
#  'eugeni': 368,
#  'european': 369,
#  'event': 370,
#  'expedit': 371,
#  'explor': 372,
#  'fail': 373,
#  'failur': 374,
#  'fascin': 375,
#  'father': 376,
#  'father’': 377,
#  'februari': 378,
#  'ferdinand': 379,
#  'fever': 380,
#  'final': 381,
#  'fine': 382,
#  'fortun': 383,
#  'françoi': 384,
#  'friend': 385,
#  'futil': 386,
#  'gener': 387,
#  'given': 388,
#  'govern': 389,
#  'great': 390,
#  'growth': 391,
#  'guilti': 392,
#  'gustav': 393,
#  'haussmann’': 394,
#  'heavili': 395,
#  'held': 396,
#  'henri': 397,
#  'histori': 398,
#  'iii': 399,
#  'immedi': 400,
#  'imperi': 401,
#  'imprison': 402,
#  'inabl': 403,
#  'inspir': 404,
#  'intern': 405,
#  'ismail': 406,
#  'jail': 407,
#  'jean': 408,
#  'journalist': 409,
#  'journei': 410,
#  'khediv': 411,
#  'land': 412,
#  'laqueur': 413,
#  'larg': 414,
#  'later': 415,
#  'leader': 416,
#  'lessep': 417,
#  'lessep‘': 418,
#  'lessep’': 419,
#  'level': 420,
#  'linant': 421,
#  'liquid': 422,
#  'lisbon': 423,
#  'lock': 424,
#  'malaria': 425,
#  'mari': 426,
#  'maritim': 427,
#  'mathieu': 428,
#  'medic': 429,
#  'mediterranean': 430,
#  'mehemet': 431,
#  'middl': 432,
#  'minist': 433,
#  'misjudg': 434,
#  'mismanag': 435,
#  'modifi': 436,
#  'mougel': 437,
#  'napoleon': 438,
#  'napoleon‘': 439,
#  'niemey': 440,
#  'occupi': 441,
#  'offic': 442,
#  'offici': 443,
#  'onlin': 444,
#  'opposit': 445,
#  'organ': 446,
#  'oscar': 447,
#  'overcom': 448,
#  'ow': 449,
#  'paid': 450,
#  'panama': 451,
#  'pari': 452,
#  'pasha': 453,
#  'perish': 454,
#  'permiss': 455,
#  'persuad': 456,
#  'pickax': 457,
#  'plan': 458,
#  'polit': 459,
#  'politician': 460,
#  'port': 461,
#  'posit': 462,
#  'post': 463,
#  'prevent': 464,
#  'prime': 465,
#  'prison': 466,
#  'prof': 467,
#  'profess': 468,
#  'project': 469,
#  'provid': 470,
#  'public': 471,
#  'pérous': 472,
#  'read': 473,
#  'recommend': 474,
#  'red': 475,
#  'reduc': 476,
#  'refer': 477,
#  'relat': 478,
#  'renov': 479,
#  'retir': 480,
#  'return': 481,
#  'rout': 482,
#  'rumor': 483,
#  'said': 484,
#  'sail': 485,
#  'scandal': 486,
#  'scheme': 487,
#  'scienc': 488,
#  'sea': 489,
#  'seen': 490,
#  'sentenc': 491,
#  'share': 492,
#  'ship': 493,
#  'slightli': 494,
#  'sold': 495,
#  'son': 496,
#  'soon': 497,
#  'spain': 498,
#  'spent': 499,
#  'stage': 500,
#  'subsequ': 501,
#  'substanti': 502,
#  'suez': 503,
#  'sultan': 504,
#  'supervis': 505,
#  'surveyor': 506,
#  'survivor': 507,
#  'thoma': 508,
#  'tower': 509,
#  'trade': 510,
#  'treat': 511,
#  'trial': 512,
#  'tunisia': 513,
#  'uncl': 514,
#  'undertak': 515,
#  'univers': 516,
#  'universel': 517,
#  'us': 518,
#  'versail': 519,
#  'vice': 520,
#  'viceroi': 521,
#  'vicomt': 522,
#  'visionari': 523,
#  'visit': 524,
#  'voyag': 525,
#  'warm': 526,
#  'welcom': 527,
#  'west': 528,
#  'western': 529,
#  'wish': 530,
#  'yellow': 531,
#  'yvelin': 532,
#  'zenith”': 533,
#  '“european': 534,
#  'aboard': 535,
#  'accident': 536,
#  'accompani': 537,
#  'ad': 538,
#  'angri': 539,
#  'appeal': 540,
#  'appear': 541,
#  'arrang': 542,
#  'audienc': 543,
#  'band': 544,
#  'beat': 545,
#  'bed': 546,
#  'bell': 547,
#  'black': 548,
#  'board': 549,
#  'boat’': 550,
#  'bridg': 551,
#  'brother': 552,
#  'came': 553,
#  'captain': 554,
#  'cartoon': 555,
#  'cartoons‘': 556,
#  'chappatt': 557,
#  'charact': 558,
#  'citi': 559,
#  'click': 560,
#  'coloni': 561,
#  'consist': 562,
#  'dave': 563,
#  'debut': 564,
#  'disnei': 565,
#  'disney’': 566,
#  'distribut': 567,
#  'distributor': 568,
#  'doubt': 569,
#  'effects‘': 570,
#  'employe': 571,
#  'eventu': 572,
#  'fall': 573,
#  'fame': 574,
#  'fight': 575,
#  'finish': 576,
#  'fleischer’': 577,
#  'flickr': 578,
#  'forth': 579,
#  'freshwat': 580,
#  'fun': 581,
#  'get': 582,
#  'girlfriend': 583,
#  'green': 584,
#  'hire': 585,
#  'impress': 586,
#  'increas': 587,
#  'indic': 588,
#  'initi': 589,
#  'inkwel': 590,
#  'instal': 591,
#  'instant': 592,
#  'intend': 593,
#  'knock': 594,
#  'like': 595,
#  'live': 596,
#  'lost': 597,
#  'love': 598,
#  'lucki': 599,
#  'make': 600,
#  'mark': 601,
#  'max': 602,
#  'meant': 603,
#  'mice': 604,
#  'mickei': 605,
#  'mickey’': 606,
#  'microphon': 607,
#  'mid': 608,
#  'minni': 609,
#  'mous': 610,
#  'mouse‘': 611,
#  'mouth': 612,
#  'movi': 613,
#  'music': 614,
#  'musician': 615,
#  'notabl': 616,
#  'novelti': 617,
#  'optic': 618,
#  'oswald': 619,
#  'parrot': 620,
#  'partli': 621,
#  'patrick': 622,
#  'peel': 623,
#  'percuss': 624,
#  'person': 625,
#  'pete': 626,
#  'phonofilm': 627,
#  'potato': 628,
#  'power': 629,
#  'precis': 630,
#  'premier': 631,
#  'present': 632,
#  'probabl': 633,
#  'proce': 634,
#  'profession': 635,
#  'rabbit': 636,
#  'real': 637,
#  'realiz': 638,
#  'releas': 639,
#  'right': 640,
#  'rise': 641,
#  'river': 642,
#  'screen': 643,
#  'sheet': 644,
#  'silent': 645,
#  'small': 646,
#  'sound': 647,
#  'soundtrack': 648,
#  'speaker': 649,
#  'star': 650,
#  'steamboat': 651,
#  'steer': 652,
#  'studio': 653,
#  'synchron': 654,
#  'test': 655,
#  'theater': 656,
#  'throw': 657,
#  'track': 658,
#  'trip': 659,
#  'unfortun': 660,
#  'universal’': 661,
#  'user': 662,
#  'walk': 663,
#  'walt': 664,
#  'whistl': 665,
#  'willi': 666,
#  'willie‘': 667,
#  'willie’': 668,
#  'wive': 669,
#  '‘mickei': 670,
#  '‘special': 671,
#  '‘steamboat': 672,
#  'achiev': 673,
#  'administr': 674,
#  'albert': 675,
#  'applic': 676,
#  'arnold': 677,
#  'atom': 678,
#  'award': 679,
#  'background': 680,
#  'berlin': 681,
#  'bildung': 682,
#  'bomb': 683,
#  'budapest': 684,
#  'chain': 685,
#  'chicago': 686,
#  'citizen': 687,
#  'clinton': 688,
#  'conscious': 689,
#  'conserv': 690,
#  'contain': 691,
#  'contribut': 692,
#  'convert': 693,
#  'cool': 694,
#  'crystallographi': 695,
#  'david': 696,
#  'decai': 697,
#  'design': 698,
#  'dewitt': 699,
#  'director': 700,
#  'disappoint': 701,
#  'discoveri': 702,
#  'dissoci': 703,
#  'doctor': 704,
#  'einstein': 705,
#  'elementari': 706,
#  'enjoi': 707,
#  'enrico': 708,
#  'eugen': 709,
#  'fermi': 710,
#  'firm': 711,
#  'foundat': 712,
#  'franklin': 713,
#  'fundament': 714,
#  'german': 715,
#  'goeppert': 716,
#  'gone': 717,
#  'gradeplutonium': 718,
#  'graphit': 719,
#  'göttingen': 720,
#  'han': 721,
#  'have': 722,
#  'hilbert': 723,
#  'hilbert‘': 724,
#  'hinduism': 725,
#  'hungarian': 726,
#  'idea': 727,
#  'independ': 728,
#  'institut': 729,
#  'introduc': 730,
#  'januari': 731,
#  'jensen': 732,
#  'juli': 733,
#  'kaiser': 734,
#  'karl': 735,
#  'laboratori': 736,
#  'laid': 737,
#  'led': 738,
#  'left': 739,
#  'letter': 740,
#  'leó': 741,
#  'life': 742,
#  'logic': 743,
#  'manhattan': 744,
#  'maria': 745,
#  'mathematician': 746,
#  'matrix': 747,
#  'mayer': 748,
#  'medal': 749,
#  'meet': 750,
#  'michael': 751,
#  'moder': 752,
#  'molecul': 753,
#  'molecules”': 754,
#  'molekülen': 755,
#  'nation': 756,
#  'nazi': 757,
#  'near': 758,
#  'neutron': 759,
#  'neutron‘': 760,
#  'newspap': 761,
#  'nonetheless': 762,
#  'nuclear': 763,
#  'nucleu': 764,
#  'oak': 765,
#  'occur': 766,
#  'offer': 767,
#  'paper': 768,
#  'particl': 769,
#  'particularli': 770,
#  'pass': 771,
#  'paul': 772,
#  'pervad': 773,
#  'philosoph': 774,
#  'philosophi': 775,
#  'physicist': 776,
#  'pile': 777,
#  'polanyi': 778,
#  'possibl': 779,
#  'presid': 780,
#  'princeton': 781,
#  'principl': 782,
#  'product': 783,
#  'prove': 784,
#  'quantum': 785,
#  'rai': 786,
#  'rate': 787,
#  'reaction': 788,
#  'reactor': 789,
#  'request': 790,
#  'rest': 791,
#  'result': 792,
#  'ridg': 793,
#  'roosevelt': 794,
#  'rule': 795,
#  'saw': 796,
#  'shift': 797,
#  'short': 798,
#  'sommerfeld': 799,
#  'spend': 800,
#  'state': 801,
#  'structur': 802,
#  'studi': 803,
#  'symmetri': 804,
#  'szilárd': 805,
#  'tanneri': 806,
#  'team': 807,
#  'tempera': 808,
#  'tenn': 809,
#  'term': 810,
#  'theoret': 811,
#  'theori': 812,
#  'thesi': 813,
#  'thing': 814,
#  'thought': 815,
#  'tyler': 816,
#  'und': 817,
#  'unit': 818,
#  'uranium': 819,
#  'urg': 820,
#  'vanish': 821,
#  'vedanta': 822,
#  'von': 823,
#  'want': 824,
#  'water': 825,
#  'weapon': 826,
#  'weissenberg': 827,
#  'wick': 828,
#  'wigner': 829,
#  'wigner’': 830,
#  'wilhelm': 831,
#  'wisconsin': 832,
#  'won': 833,
#  'world’': 834,
#  'zerfal': 835,
#  '‘atom': 836,
#  '“format': 837,
#  'abstract': 838,
#  'academ': 839,
#  'accademia': 840,
#  'acquir': 841,
#  'addit': 842,
#  'appli': 843,
#  'artist': 844,
#  'austrian': 845,
#  'axiomat': 846,
#  'beltrami': 847,
#  'beltrami–klein': 848,
#  'beltrami’': 849,
#  'bologna': 850,
#  'bolyai': 851,
#  'brioschi': 852,
#  'capit': 853,
#  'case': 854,
#  'certainli': 855,
#  'chair': 856,
#  'circl': 857,
#  'clariti': 858,
#  'concept': 859,
#  'concern': 860,
#  'constant': 861,
#  'correspond': 862,
#  'cremona': 863,
#  'curvatur': 864,
#  'curvature“': 865,
#  'dei': 866,
#  'deriv': 867,
#  'differenti': 868,
#  'dimens': 869,
#  'dimension': 870,
#  'discontinu': 871,
#  'disk': 872,
#  'elast': 873,
#  'electr': 874,
#  'empir': 875,
#  'enthusiast': 876,
#  'equiconsist': 877,
#  'escher': 878,
#  'especi': 879,
#  'establish': 880,
#  'euclidean': 881,
#  'euclidian': 882,
#  'eugenio': 883,
#  'expel': 884,
#  'exposit': 885,
#  'fashion': 886,
#  'formula': 887,
#  'formulas”': 888,
#  'francesco': 889,
#  'function': 890,
#  'geodes': 891,
#  'geometri': 892,
#  'geometry“': 893,
#  'ghislieri': 894,
#  'half': 895,
#  'hard': 896,
#  'hardship': 897,
#  'hyperbol': 898,
#  'illustr': 899,
#  'influenc': 900,
#  'inherit': 901,
#  'interpret': 902,
#  'invigor': 903,
#  'italian': 904,
#  'kingdom': 905,
#  'limit': 906,
#  'lincei': 907,
#  'line': 908,
#  'lobachevski': 909,
#  'lombardi': 910,
#  'lombardy–venic': 911,
#  'lover': 912,
#  'magnet': 913,
#  'matematich': 914,
#  'mathemat': 915,
#  'memoir': 916,
#  'milan': 917,
#  'mind': 918,
#  'miniatur': 919,
#  'model': 920,
#  'move': 921,
#  'musicrath': 922,
#  'neg': 923,
#  'non': 924,
#  'note': 925,
#  'obtain': 926,
#  'oper': 927,
#  'opinion': 928,
#  'ordinari': 929,
#  'paint': 930,
#  'pavia': 931,
#  'plane': 932,
#  'poincaré': 933,
#  'posthum': 934,
#  'previous': 935,
#  'professor': 936,
#  'proof': 937,
#  'propos': 938,
#  'pseudospher': 939,
#  'railroad': 940,
#  'ration': 941,
#  'recept': 942,
#  'recogn': 943,
#  'relationship': 944,
#  'remark': 945,
#  'replac': 946,
#  'repres': 947,
#  'rome': 948,
#  'scene': 949,
#  'second': 950,
#  'secretari': 951,
#  'senat': 952,
#  'set': 953,
#  'space': 954,
#  'spheric': 955,
#  'surfac': 956,
#  'talent': 957,
#  'taught': 958,
#  'theorem': 959,
#  'thermodynam': 960,
#  'todai': 961,
#  'topic': 962,
#  'transform': 963,
#  'triangl': 964,
#  'trigonometr': 965,
#  'trigonometri': 966,
#  'usual': 967,
#  'verona': 968,
#  'volum': 969,
#  'wildberg': 970,
#  '“essay”': 971,
#  '“fundament': 972,
#  '“mathhist': 973,
#  '“trigonometr': 974,
#  'action': 975,
#  'adam': 976,
#  'advoc': 977,
#  'automat': 978,
#  'be': 979,
#  'bee': 980,
#  'believ': 981,
#  'benefit': 982,
#  'bernard': 983,
#  'brutorum': 984,
#  'cartesian': 985,
#  'chylosi': 986,
#  'collaps': 987,
#  'collect': 988,
#  'dai': 989,
#  'degrad': 990,
#  'degre': 991,
#  'describ': 992,
#  'desir': 993,
#  'detail': 994,
#  'discuss': 995,
#  'divis': 996,
#  'dutch': 997,
#  'econom': 998,
#  'economist': 999,
#  ...}

# %% [markdown]
# ### Creación Vectorial ponderada ti_idf

# %% [markdown]
# Aca crearemos un iterador que convierte documentos de texto a su representación de bolsa de palabras (Bag of Words, BOW).
#
# Al iterar sobre instancias de esta clase, cada documento en el corpus se convierte en un vector BOW utilizando
# un vocabulario predefinido. Esta conversión es esencial para modelos que requieren entradas numéricas como TF-IDF.

# %%
class Bow_Corpus:
    def __iter__(self):
        for doc in corpus:
            # Vectorización del texto por documento
            yield vocabulario.doc2bow(doc)

bow_corpus = Bow_Corpus()


for doc in bow_corpus:
    print(doc)



# Entrenamiento del modelo TF-IDF
tfidf = models.TfidfModel(bow_corpus, normalize=True) # normalize=True normaliza los valores en el rango [0, 1]
print(tfidf)

# Aplicar el modelo TF-IDF al corpus
tfidf_corpus = tfidf[bow_corpus]


# Imnprimer los vectores TF-IDF
for doc in tfidf_corpus:
    print(doc)

#Guardamos el corpus en un archivo
tfidf.save('simple_corpus_GENSIM.tfidf')
# Out:
# [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1), (6, 3), (7, 2), (8, 1), (9, 11), (10, 1), (11, 1), (12, 1), (13, 1), (14, 1), (15, 2), (16, 1), (17, 1), (18, 1), (19, 1), (20, 3), (21, 1), (22, 1), (23, 2), (24, 1), (25, 1), (26, 1), (27, 1), (28, 1), (29, 10), (30, 1), (31, 1), (32, 2), (33, 1), (34, 1), (35, 1), (36, 1), (37, 2), (38, 1), (39, 1), (40, 1), (41, 1), (42, 2), (43, 2), (44, 1), (45, 3), (46, 1), (47, 1), (48, 5), (49, 1), (50, 1), (51, 2), (52, 2), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 1), (59, 2), (60, 1), (61, 2), (62, 1), (63, 1), (64, 3), (65, 1), (66, 1), (67, 1), (68, 2), (69, 1), (70, 2), (71, 3), (72, 2), (73, 1), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (79, 1), (80, 1), (81, 1), (82, 1), (83, 1), (84, 1), (85, 2), (86, 1), (87, 2), (88, 1), (89, 1), (90, 1), (91, 1), (92, 1), (93, 1), (94, 2), (95, 1), (96, 1), (97, 1), (98, 2), (99, 2), (100, 1), (101, 1), (102, 1), (103, 1), (104, 1), (105, 1), (106, 1), (107, 1), (108, 1), (109, 1), (110, 1), (111, 1), (112, 1), (113, 2), (114, 1), (115, 1), (116, 1), (117, 1), (118, 1), (119, 1), (120, 1), (121, 1), (122, 4), (123, 1), (124, 1), (125, 2), (126, 2), (127, 1), (128, 1), (129, 1), (130, 1), (131, 1), (132, 1), (133, 1), (134, 1), (135, 1), (136, 1), (137, 5), (138, 1), (139, 4), (140, 2), (141, 1), (142, 1), (143, 1), (144, 1), (145, 2)]
# [(11, 2), (14, 5), (15, 1), (24, 1), (38, 1), (41, 1), (52, 1), (59, 1), (64, 2), (83, 1), (88, 1), (106, 5), (134, 1), (136, 1), (138, 1), (142, 1), (143, 1), (146, 1), (147, 1), (148, 1), (149, 1), (150, 1), (151, 1), (152,
2655, 0.016278837723417747), (2663, 0.06089120423701657), (2925, 0.02916031435726706), (3050, 0.03469840153786735), (3075, 0.020584378974843345), (3143, 0.038601149279944506), (3256, 0.10804990913659525), (3294, 0.03469840153786735), (3354, 0.019871063044053807), (3364, 0.035832105689644365), (3456, 0.021904989198730636), (3719, 0.02802661020549003), (3755, 0.03469840153786735), (3759, 0.046219459084143294), (3887, 0.03711739345088559), (3975, 0.02857678053110795), (4059, 0.029781520874448957), (4264, 0.11580344783983354), (4390, 0.15579459024648912), (4508, 0.08071211989780687), (4587, 0.040356059948903435), (4628, 0.040356059948903435), (5471, 0.22936811659019976), (6618, 0.049175688354398985), (7093, 0.049175688354398985), (7477, 0.049175688354398985), (7975, 0.049175688354398985), (8086, 0.20178029974451717), (8523, 0.045272940612321816), (8582, 0.049175688354398985), (9468, 0.049175688354398985), (9865, 0.03711739345088559), (13629, 0.049175688354398985), (13842, 0.24587844177199494), (14422, 0.11169495937355259), (14423, 0.6701697562413155), (14424, 0.055847479686776294), (14425, 0.055847479686776294), (14426, 0.055847479686776294), (14427, 0.055847479686776294), (14428, 0.055847479686776294), (14429, 0.055847479686776294), (14430, 0.055847479686776294), (14431, 0.055847479686776294), (14432, 0.055847479686776294), (14433, 0.055847479686776294), (14434, 0.11169495937355259), (14435, 0.055847479686776294), (14436, 0.055847479686776294), ...

# %% [markdown]
# ### Similitud Coseno
#
# Calcula la similitud coseno entre dos documentos en un corpus TF-IDF utilizando Gensim.

# %%
def simil_coseno_gensim(doc_index1, doc_index2, tfidf_model, corpus):
    
    # Crea el índice de similitudes si aún no existe
    tfidf_corpus = list(tfidf[bow_corpus])   
    index = similarities.MatrixSimilarity(tfidf_corpus)

    # Obtener la similitud coseno usando el índice
    similitudes = index[tfidf_corpus[doc_index1]]
    coseno = similitudes[doc_index2]
    
    return coseno


#### EJEMPLO
doc_index1 = 0  
doc_index2 = 1  

# Calcula la similitud coseno entre dos documentos específicos
coseno_simil = simil_coseno_gensim(doc_index1, doc_index2, tfidf, tfidf_corpus)
print(f"Similitud coseno entre los documentos {doc_index1} y {doc_index2}: {coseno_simil}")
# Out:
# Similitud coseno entre los documentos 0 y 1: 0.004058283753693104

# %%
### Procesamiento de Queries

queries = tokenizar_documentos(path_queries)

vocabulario = corpora.Dictionary(corpus + queries)  # Unificar vocabulario

print(corpus)
print(queries)
print(vocabulario)

# Generación de corpus en formato BOW y TF-IDF
bow_corpus = [vocabulario.doc2bow(doc) for doc in corpus]
tfidf_model = models.TfidfModel(bow_corpus)
tfidf_corpus = [tfidf_model[doc] for doc in bow_corpus]

# Índice de similitudes
index = similarities.MatrixSimilarity(tfidf_corpus)
# Out:
# [['william', 'beaumont', 'human', 'digest', 'william', 'beaumont', 'physiolog', 'digest', 'imag', 'sourc', 'novemb', 'american', 'surgeon', 'william', 'beaumont', 'born', 'best', 'known', '“father', 'gastric', 'physiology”', 'follow', 'research', 'human', 'digest', 'william', 'beaumont', 'born', 'lebanon', 'connecticut', 'physician', 'serv', 'surgeon’', 'mate', 'armi', 'war', 'open', 'privat',
hurt', 'anim', 'family’', 'farm', 'boi', 'catch', 'tomt', 'famili', 'church', 'nil', 'refus', 'let', 'tomt', 'free', 'turn', 'tomt', 'shrunken', 'boi', 'abl', 'talk', 'farm', 'anim', 'delight', 'nil', 'tini', 'seek', 'reveng', 'wild', 'gees', 'fly', 'farm', 'white', 'farm', 'goos', 'attempt', 'join', 'nil', 'hold', 'bird’', 'neck', 'successfulli', 'take', 'join', 'wild', 'bird', 'pleas', 'join', 'boi', 'domest', 'goos', 'adventur', 'sweden', 'goos', 'nil', 'accomplish', 'task', 'order', 'accept', 'group', 'nil', 'learn', 'tomt', 'chang', 'regular', 'size', 'good', 'stori', 'nils’', 'adventur', 'known', 'sweden', 'pictur', 'nil', 'holgersson', 'goos', 'fly', 'plain', 'scania', 'print', 'revers' ...
# [['fabric', 'music', 'instrument'], ['famou', 'german', 'poetri'], ['romantic'], ['univers', 'edinburgh', 'research'], ['bridg', 'construct'], ['walk', 'fame', 'star'], ['scientist', 'work', 'atom', 'bomb'], ['invent', 'internet'], ['earli', 'telecommun', 'method'], ['explor', 'south', 'pole'], ['famou', 'member', 'royal', 'navi'], ['nobel', 'prize', 'win', 'invent'], ['south', 'america'], ['edward', 'teller', 'mari', 'curi'], ['comput', 'languag', 'program', 'artifici', 'intellig'], ['william', 'hearst', 'movi'], ['captain', 'jame', 'cook', 'explor'], ['grace', 'hopper', 'famou'], ['comput', 'astronomi'], ['wwii', 'aircraft'], ['literari', 'critic', 'thoma', 'moor'], ['nazi', 'confisc', 'destroi', 'art', 'literatur'], ['modern', 'ag', 'english', 'literatur'], ['modern', 'physiolog'], ['roman', 'empir'], ['scientist', 'contribut', 'photosynthesi'], ['aviat', 'pioneer', 'public'], ['gutenberg', 'bibl'], ['religi', 'belief', 'scientist', 'explor'], ['carl', 'friedrich', 'gauss', 'influenc', 'colleagu'], ['person', 'hannov'], ['skinner', 'experi', 'oper', 'condit', 'chamber'], ['napoleon', 'russian', 'campaign'], ['friend', 'enemi', 'napoleon', 'bonapart'], ['woman', 'won', 'nobel', 'prize']]
# Dictionary<14442 unique tokens: ['accid', 'acid', 'activ', 'affect', 'ag']...>

# %% [markdown]
# Se procesa una lista de consultas para determinar y registrar la similitud de cada consulta con documentos en un índice, utilizando un modelo TF-IDF y un vocabulario predefinido.

# %%
def procesar_consultas_y_documentos(queries, index, vocabulario, tfidf_model, salida_path):

    data = []  # Lista para almacenar datos para el DataFrame

    with open(salida_path, 'w') as salida_file:
        for i, query in enumerate(queries):

            query_id = f"q{i + 1:02}"
            query_bow = vocabulario.doc2bow(query)
            query_tfidf = tfidf_model[query_bow]
            similitudes = index[query_tfidf]

            # Filtrar y ordenar resultados
            resultados = []
            for idx, sim in enumerate(similitudes):
                if sim > 0:
                    resultados.append(("d{:02}".format(idx + 1), sim))
            
            # Ordenar por similitud
            resultados.sort(key=lambda x: x[1], reverse=True)

            # Formato de salida
            resultados_str = ''
            for doc_id, sim in resultados:
                resultados_str += "{}: {:.4f},".format(doc_id, sim)
            resultados_str = resultados_str.rstrip(',')  # Remover la última coma

            salida_file.write("q{:02} {}\n".format(i + 1, resultados_str))

            # Almacenar en la lista para DataFrame
            data.append({'query_id': query_id, 'docs': resultados_str})

    # Crear DataFrame
    resultados_df = pd.DataFrame(data)
    return resultados_df

resultados_df = procesar_consultas_y_documentos(queries, index, vocabulario, tfidf_model, salidaFile) # Llamada a la función y guardar el DataFrame

# %% [markdown]
# ### # PROCESAMIENTO INICIAL DEL GROUND-TRUTH

# %%
ground_truth_df = pd.read_csv(ground_truth_path, sep='\t', header=None, names=['query_id', 'doc_id_relevance'])
ground_truth_df['doc_ids'] = ground_truth_df['doc_id_relevance'].apply(lambda x: [doc.split(':')[0] for doc in x.split(',')])
ground_truth_df['relevance'] = ground_truth_df['doc_id_relevance'].apply(lambda x: [int(doc.split(':')[1]) for doc in x.split(',')])
ground_truth_df[['query_id', 'doc_ids', 'relevance']]
# Out:
#    query_id                                            doc_ids  \
# 0       q01                                 [d186, d254, d016]
# 1       q02  [d136, d139, d143, d283, d228, d164, d318, d29...
# 2       q03               [d152, d291, d283, d147, d318, d105]
# 3       q04         [d275, d010, d286, d019, d049, d330, d270]
# 4       q06               [d069, d233, d257, d297, d026, d329]
# 5       q07                           [d004, d077, d266, d179]
# 6       q08  [d205, d005, d110, d108, d117, d081, d292, d25...
# 7       q09               [d205, d199, d198, d223, d217, d177]
# 8       q10   [d068, d100, d065, d076, d231, d199, d052, d215]
# 9       q12                           [d239, d277, d258, d250]
# 10      q13                     [d239, d277, d258, d049, d056]
# 11      q14  [d002, d005, d142, d314, d280, d130, d041, d11...
# 12      q16                                       [d229, d132]
# 13      q17                           [d280, d271, d121, d091]
# 14      q18         [d207, d201, d192, d194, d222, d216, d210]
# 15      q19                                       [d077, d179]
# 16      q22         [d277, d011, d132, d258, d049, d250, d331]
# 17      q23   [d205, d202, d276, d194, d216, d219, d215, d211]
# 18      q24                     [d098, d129, d196, d221, d060]
# 19      q25                           [d167, d166, d020, d023]
# 20      q26                                             [d152]
# 21      q27   [d103, d143, d107, d051, d017, d054, d293, d158]
# 22      q28                                 [d136, d316, d094]
# 23      q29  [d001, d037, d130, d314, d046, d133, d113, d29...
# 24      q32                     [d139, d067, d025, d031, d090]
# 25      q34                                             [d248]
# 26      q36  [d277, d167, d257, d020, d023, d321, d247, d26...
# 27      q37                                 [d169, d256, d116]
# 28      q38   [d235, d039, d229, d317, d015, d250, d263, d294]
# 29      q40  [d307, d098, d042, d047, d252, d262, d112, d24...
# 30      q41         [d174, d128, d318, d291, d150, d268, d121]
# 31      q42                                 [d314, d014, d298]
# 32      q44  [d170, d003, d164, d105, d085, d254, d185, d12...
# 33      q45   [d170, d105, d164, d254, d085, d185, d126, d148]
# 34      q46               [d002, d005, d314, d133, d093, d121]
#
#                                relevance
# 0                              [4, 5, 5]
# 1      [2, 2, 4, 4, 4, 4, 2, 4, 4, 2, 2]
# 2                     [3, 4, 4, 3, 2, 2]
# 3                  [3, 3, 2, 2, 2, 2, 3]
# 4                     [2, 3, 2, 3, 4, 5]
# 5                           [3, 3, 2, 3]
# 6   [2, 4, 4, 3, 3, 2, 2, 5, 3, 3, 2, 2]
# 7                     [3, 5, 3, 2, 2, 2]
# 8               [2, 2, 3, 3, 4, 4, 2, 2]
# 9                           [4, 4, 3, 4]
# 10                       [2, 2, 2, 4, 4]
# 11  [2, 3, 2, 3, 3, 3, 3, 2, 4, 3, 4, 3]
# 12                                [2, 3]
# 13                          [2, 4, 4, 2]
# 14                 [2, 3, 4, 3, 2, 2, 3]
# 15                                [2, 5]
# 16                 [2, 3, 2, 2, 2, 2, 2]
# 17              [2, 2, 4, 2, 2, 5, 2, 3]
# 18                       [2, 3, 2, 2, 2]
# 19                          [3, 3, 3, 2]
# 20                                   [5]
# 21              [5, 2, 2, 2, 2, 5, 4, 2]
# 22                             [5, 3, 3]
# 23  [3, 5, 3, 4, 3, 4, 4, 2, 3, 2, 4, 3]
# 24                       [3, 3, 5, 2, 4]
# 25                                   [5]
# 26        [4, 2, 4, 3, 3, 3, 4, 4, 3, 3]
# 27                             [5, 2, 3]
# 28              [4, 3, 2, 2, 2, 2, 2, 4]
# 29           [3, 3, 5, 5, 2, 3, 3, 4, 3]
# 30                 [3, 3, 5, 4, 5, 2, 3]
# 31                             [2, 2, 5]
# 32        [2, 2, 2, 2, 2, 2, 3, 2, 2, 4]
# 33              [3, 5, 3, 2, 4, 3, 3, 2]
# 34                    [2, 2, 2, 3, 2, 3]

# %% [markdown]
# ### Calculo de P@M

# %%
def limpiar_identificadores(doc_ids):
    return list(set([doc.replace(')', '').strip() for doc in doc_ids]))

def calcular_precision_p_m(resultados_df, ground_truth_df):
    precision_por_query = {}
    if 'doc_ids' not in resultados_df.columns:
        resultados_df['doc_ids'] = resultados_df['docs'].apply(lambda x: [doc.split(':')[0] for doc in x.split(',')])
    resultados_df['doc_ids'] = resultados_df['doc_ids'].apply(limpiar_identificadores)   
    if 'doc_ids' not in ground_truth_df.columns:
        ground_truth_df['doc_ids'] = ground_truth_df['doc_id_relevance'].apply(lambda x: [doc.split(':')[0] for doc in x.split(',')])
    for _, row in resultados_df.iterrows():
        query_id = row['query_id']
        doc_retrieved = row['doc_ids']   
        M = len(doc_retrieved)     
        ground_truth_row = ground_truth_df[ground_truth_df['query_id'] == query_id]   
        if ground_truth_row.empty:
            precision_por_query[query_id] = 0.0
            continue
        relevancia_docs = ground_truth_row['doc_ids'].values[0]
        relevance_list = [1 if doc in relevancia_docs else 0 for doc in doc_retrieved[:M]]
        precision_p_m = sum(relevance_list) / M if M > 0 else 0.0
        precision_por_query[query_id] = precision_p_m
            
    return precision_por_query

precision_resultados = calcular_precision_p_m(resultados_df, ground_truth_df)
precisionDF = pd.DataFrame(list(precision_resultados.items()), columns=['query_id', 'precision'])
precisionDF
# Out:
#    query_id  precision
# 0       q01   0.032258
# 1       q02   0.055838
# 2       q03   1.000000
# 3       q04   0.017621
# 4       q05   0.000000
# 5       q06   0.000000
# 6       q07   0.006969
# 7       q08   0.027027
# 8       q09   0.030769
# 9       q10   0.000000
# 10      q11   0.000000
# 11      q12   0.009009
# 12      q13   0.042553
# 13      q14   0.028571
# 14      q15   0.000000
# 15      q16   0.000000
# 16      q17   0.024096
# 17      q18   0.026846
# 18      q19   0.000000
# 19      q20   0.000000
# 20      q21   0.000000
# 21      q22   0.009434
# 22      q23   0.028169
# 23      q24   0.000000
# 24      q25   0.000000
# 25      q26   0.000000
# 26      q27   0.030075
# 27      q28   0.000000
# 28      q29   0.024845
# 29      q30   0.000000
# 30      q31   0.000000
# 31      q32   0.000000
# 32      q33   0.000000
# 33      q34   0.000000
# 34      q35   0.000000

# %% [markdown]
# ### Calculo de R@M

# %%
def calcular_recall_p_m(resultados_df, ground_truth_df):
    recall_por_query = {}
    
    # Asegurarse de que los identificadores de documentos están disponibles para comparación
    if 'doc_ids' not in resultados_df.columns:
        resultados_df['doc_ids'] = resultados_df['docs'].apply(
            lambda x: [doc.split(':')[0] for doc in x.split(',')]
        )
    if 'doc_ids' not in ground_truth_df.columns:
        ground_truth_df['doc_ids'] = ground_truth_df['doc_id_relevance'].apply(
            lambda x: [doc.split(':')[0] for doc in x.split(',')]
        )
        ground_truth_df['relevancias'] = ground_truth_df['doc_id_relevance'].apply(
            lambda x: [int(doc.split(':')[1]) for doc in x.split(',')]
        )

    # Iterar sobre cada fila en resultados_df para calcular recall
    for _, row in resultados_df.iterrows():
        query_id = row['query_id']
        doc_retrieved = row['doc_ids']
        # Encontrar la fila correspondiente en ground_truth_df
        ground_truth_row = ground_truth_df[ground_truth_df['query_id'] == query_id]

        # Comprobar si hay datos relevantes para esta consulta
        if ground_truth_row.empty or not ground_truth_row['doc_ids'].values[0]:
            recall_por_query[query_id] = 0.0
            continue

        # Lista de documentos relevantes
        relevancia_docs = ground_truth_row['doc_ids'].values[0]
        num_total_relevant_docs = len(relevancia_docs)
        # Crear una lista de relevancia binaria para los documentos recuperados
        relevance_list = [1 if doc in relevancia_docs else 0 for doc in doc_retrieved]
        
        # Calcular recall como la suma de los relevantes recuperados dividida por el total de relevantes
        recall_p_m = sum(relevance_list) / num_total_relevant_docs if num_total_relevant_docs > 0 else 0
        recall_por_query[query_id] = recall_p_m
    
    return recall_por_query

# Suponiendo que resultados_df y ground_truth_df ya están definidos
recall_resultados = calcular_recall_p_m(resultados_df, ground_truth_df)
recallDF = pd.DataFrame(list(recall_resultados.items()), columns=['query_id', 'recall'])
print(recallDF)
# Out:
#    query_id    recall
# 0       q01  0.666667
# 1       q02  1.000000
# 2       q03  1.000000
# 3       q04  0.571429
# 4       q05  0.000000
# 5       q06  0.000000
# 6       q07  0.500000
# 7       q08  0.166667
# 8       q09  1.000000
# 9       q10  0.000000
# 10      q11  0.000000
# 11      q12  0.250000
# 12      q13  0.400000
# 13      q14  0.083333
# 14      q15  0.000000
# 15      q16  0.000000
# 16      q17  0.500000
# 17      q18  0.571429
# 18      q19  0.000000
# 19      q20  0.000000
# 20      q21  0.000000
# 21      q22  0.142857
# 22      q23  0.750000
# 23      q24  0.000000
# 24      q25  0.000000
# 25      q26  0.000000
# 26      q27  0.500000
# 27      q28  0.000000
# 28      q29  0.333333
# 29      q30  0.000000
# 30      q31  0.000000
# 31      q32  0.000000
# 32      q33  0.000000
# 33      q34  0.000000
# 34      q35  0.000000

# %% [markdown]
# ### Calculo del NDCG@M

# %%
def calcular_dcg(relevancias, M):
    return sum((relevancia / np.log2(idx + 2)) for idx, relevancia in enumerate(relevancias[:M]))

def calcular_ndcg_p_m(resultados_df, ground_truth_df):
    ndcg_por_query = {}
    if 'doc_ids' not in resultados_df.columns:
        resultados_df['doc_ids'] = resultados_df['docs'].apply(lambda x: [doc.split(':')[0] for doc in x.split(',')])
    resultados_df['doc_ids'] = resultados_df['doc_ids'].apply(limpiar_identificadores)
    if 'doc_ids' not in ground_truth_df.columns:
        ground_truth_df['doc_ids'] = ground_truth_df['doc_id_relevance'].apply(lambda x: [doc.split(':')[0] for doc in x.split(',')]) 
    ground_truth_df['relevancias'] = ground_truth_df['doc_id_relevance'].apply(lambda x: [int(doc.split(':')[1]) for doc in x.split(',')])
    for _, row in resultados_df.iterrows():
        query_id = row['query_id']
        doc_retrieved = row['doc_ids'] 
        ground_truth_row = ground_truth_df[ground_truth_df['query_id'] == query_id]
        if ground_truth_row.empty:
            ndcg_por_query[query_id] = 0.0
            continue       
        relevancia_docs = ground_truth_row['doc_ids'].values[0]
        relevancias_reales = ground_truth_row['relevancias'].values[0]

        M = len(relevancia_docs)      
        relevancias_obtenidas = [relevancias_reales[relevancia_docs.index(doc)] if doc in relevancia_docs else 0 for doc in doc_retrieved[:M]]
        dcg = calcular_dcg(relevancias_obtenidas, M)
        relevancias_ideales = sorted(relevancias_reales, reverse=True)
        idcg = calcular_dcg(relevancias_ideales, M)
        ndcg_p_m = dcg / idcg if idcg > 0 else 0.0
        ndcg_por_query[query_id] = ndcg_p_m
    
    return ndcg_por_query

ndcg_resultados = calcular_ndcg_p_m(resultados_df, ground_truth_df)
ndcgDF = pd.DataFrame(list(ndcg_resultados.items()), columns=['query_id', 'ndcg'])
ndcgDF
# Out:
#    query_id      ndcg
# 0       q01  0.000000
# 1       q02  0.000000
# 2       q03  0.881896
# 3       q04  0.000000
# 4       q05  0.000000
# 5       q06  0.000000
# 6       q07  0.000000
# 7       q08  0.330419
# 8       q09  0.000000
# 9       q10  0.000000
# 10      q11  0.000000
# 11      q12  0.000000
# 12      q13  0.000000
# 13      q14  0.000000
# 14      q15  0.000000
# 15      q16  0.000000
# 16      q17  0.000000
# 17      q18  0.000000
# 18      q19  0.000000
# 19      q20  0.000000
# 20      q21  0.000000
# 21      q22  0.000000
# 22      q23  0.000000
# 23      q24  0.000000
# 24      q25  0.000000
# 25      q26  0.000000
# 26      q27  0.000000
# 27      q28  0.000000
# 28      q29  0.000000
# 29      q30  0.000000
# 30      q31  0.000000
# 31      q32  0.000000
# 32      q33  0.000000
# 33      q34  0.000000
# 34      q35  0.000000

# %% [markdown]
# ### Calculo de la metrica de evaluación 𝑁𝐷𝐶𝐺@𝑀

# %%
def calcular_dcg(relevancias, M):
    return sum((relevancia / np.log2(idx + 2)) for idx, relevancia in enumerate(relevancias[:M]))

def calcular_ndcg_p_m(resultados_df, ground_truth_df):
    ndcg_por_query = {}
    
    for _, row in resultados_df.iterrows():
        query_id = row['query_id']
        doc_retrieved = row['doc_ids'] 
        ground_truth_row = ground_truth_df[ground_truth_df['query_id'] == query_id]

        if ground_truth_row.empty or 'doc_ids' not in ground_truth_row.columns or 'relevancias' not in ground_truth_row.columns:
            ndcg_por_query[query_id] = 0.0
            continue

        relevancia_docs = ground_truth_row['doc_ids'].values[0]
        relevancias_reales = ground_truth_row['relevancias'].values[0]
        M = min(len(doc_retrieved), len(relevancia_docs))
        
        relevancias_obtenidas = [relevancias_reales[relevancia_docs.index(doc)] if doc in relevancia_docs else 0 for doc in doc_retrieved[:M]]
        dcg = calcular_dcg(relevancias_obtenidas, M)
        relevancias_ideales = sorted(relevancias_reales, reverse=True)
        idcg = calcular_dcg(relevancias_ideales, M)
        ndcg_p_m = dcg / idcg if idcg > 0 else 0.0
        ndcg_por_query[query_id] = ndcg_p_m
    
    return ndcg_por_query

# Asegúrate de que resultados_df y ground_truth_df están correctamente preparados
ndcg_resultados = calcular_ndcg_p_m(resultados_df, ground_truth_df)
ndcgDF = pd.DataFrame(list(ndcg_resultados.items()), columns=['query_id', 'ndcg'])
print(ndcgDF)
# Out:
#    query_id      ndcg
# 0       q01  0.000000
# 1       q02  0.000000
# 2       q03  0.881896
# 3       q04  0.000000
# 4       q05  0.000000
# 5       q06  0.000000
# 6       q07  0.000000
# 7       q08  0.330419
# 8       q09  0.000000
# 9       q10  0.000000
# 10      q11  0.000000
# 11      q12  0.000000
# 12      q13  0.000000
# 13      q14  0.000000
# 14      q15  0.000000
# 15      q16  0.000000
# 16      q17  0.000000
# 17      q18  0.000000
# 18      q19  0.000000
# 19      q20  0.000000
# 20      q21  0.000000
# 21      q22  0.000000
# 22      q23  0.000000
# 23      q24  0.000000
# 24      q25  0.000000
# 25      q26  0.000000
# 26      q27  0.000000
# 27      q28  0.000000
# 28      q29  0.000000
# 29      q30  0.000000
# 30      q31  0.000000
# 31      q32  0.000000
# 32      q33  0.000000
# 33      q34  0.000000
# 34      q35  0.000000

# %% [markdown]
# # Calculo de la metrica de evaluación 𝑀𝐴𝑃

# %%
def calcular_precision_acumulada(relevance_list):
    precisiones = []
    num_relevant = 0
    for i, relevancia in enumerate(relevance_list):
        if relevancia == 1:
            num_relevant += 1
            precisiones.append(num_relevant / (i + 1))  
    if precisiones:
        return sum(precisiones) / len(precisiones)
    else:
        return 0.0

def calcular_map(resultados_df, ground_truth_df):
    average_precisions = []
    if 'doc_ids' not in resultados_df.columns:
        resultados_df['doc_ids'] = resultados_df['docs'].apply(lambda x: [doc.split(':')[0] for doc in x.split(',')]) 
    resultados_df['doc_ids'] = resultados_df['doc_ids'].apply(limpiar_identificadores)
    if 'doc_ids' not in ground_truth_df.columns:
        ground_truth_df['doc_ids'] = ground_truth_df['doc_id_relevance'].apply(lambda x: [doc.split(':')[0] for doc in x.split(',')])
    ground_truth_df['relevancias'] = ground_truth_df['doc_id_relevance'].apply(lambda x: [int(doc.split(':')[1]) for doc in x.split(',')])
    for _, row in resultados_df.iterrows():
        query_id = row['query_id']
        doc_retrieved = row['doc_ids']  
        ground_truth_row = ground_truth_df[ground_truth_df['query_id'] == query_id]
        if ground_truth_row.empty:
            average_precisions.append(0.0)
            continue
        relevancia_docs = ground_truth_row['doc_ids'].values[0]
        relevance_list = [1 if doc in relevancia_docs else 0 for doc in doc_retrieved]
        avg_precision = calcular_precision_acumulada(relevance_list)
        average_precisions.append(avg_precision)
    map_score = sum(average_precisions) / len(average_precisions) if average_precisions else 0.0
    return map_score

# Ejemplo de uso
map_score = calcular_map(resultados_df, ground_truth_df)
print("\nMAP (Mean Average Precision):", map_score)
# Out:
# MAP (Mean Average Precision): 0.058783838384159064
